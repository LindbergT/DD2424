# %% [markdown]
# # CIFAR-10 dataset - ResNet
#
# In this notebook, I am going to assess the performances of ResNet for image classifications on the images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects.
#
# The experimental process is the following:
#
# - Import CIFAR-10 dataset
# - Pre-process the data
#     - Normalization of the images
#     - One hot encoding of the labels
# - Import the base model pre trained on Image Net
# - Freeze the weights
# - Add a simple output network
# - Fine tune the overall network by training the last layer
# - Analyse results
#
# All the implementation will be carried out in Keras (tensorflow backend) on our personal laptops.

# %% [markdown]
# ## Data Import
#
# The utilities function to download the dataset have been partially reused from the code shared by Park Chansung through [his medium article](https://towardsdatascience.com/transfer-learning-in-tensorflow-9e4f7eae3bb4).

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm 
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DownloadProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num
        
if not isfile('cifar-10-python.tar.gz'):
    with DownloadProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_label_names():
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
image_size = 32

def load_cfar10_batch(cifar10_dataset_folder_path, batch_id):
    with open(cifar10_dataset_folder_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        # note the encoding type is 'latin1'
        batch = pickle.load(file, encoding='latin1')
        
    features = batch['data'].reshape((len(batch['data']), 3, image_size, image_size)).transpose(0, 2, 3, 1)
    labels = batch['labels']
        
    return features, labels

# %% [markdown]
# ## Preprocess the Data to Merge Batches and Prepare the Split
#
# The CIFRAR dataset is provided divided into multiple files (batches). We will now merge all the batches into one single set of training data. Given the utilities provided by Keras we do not need to apply any Train-Validation split as it will be automatically be performed by the training procedure.
#
# This does introduce a small bias due to the fact that validation items are normalised together with the training data and not separately. Given that the validation split only compares the model with itself we do not need to take care about this bias as long as its existance is acknowledged when evaluating the absolute value of the validation loss.
#
# The test data is also loaded and preprocessed independently.

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import to_categorical
from copy import deepcopy
import time

session_id = int(time.time())

def preprocess_and_save(features, labels, filename=None):
    features = preprocess_input(features)
    labels = to_categorical(labels)
    if filename is not None:
        pickle.dump((features, labels), open(filename, 'wb'))
    return features, labels

def build_and_save_splits(cifar10_dataset_folder_path):
    n_batches = 5
    valid_features = []
    valid_labels = []
    features = np.empty((0,32,32,3))
    labels = []
    
    for batch_i in range(1, n_batches + 1):
        features_, labels_ = load_cfar10_batch(cifar10_dataset_folder_path, batch_i)
        features = np.concatenate((features,features_))
        labels += labels_
    
    original_features = deepcopy(features)
    # validation_size = int(len(features) * 0.1)
    X_train, y_train = preprocess_and_save(features, labels, "data/{}-train.pkl".format(session_id))
    # X_val, y_val = preprocess_and_save(features[-validation_size:], labels[-validation_size:], "data/validation.pkl")

    
    # load the test dataset
    with open(cifar10_dataset_folder_path + '/test_batch', mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    # preprocess the testing data
    test_features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    test_labels = batch['labels']
    original_test_features = deepcopy(test_features)
    
    # Preprocess and Save all testing data
    X_test, y_test = preprocess_and_save(np.array(test_features), np.array(test_labels),
                         'data/{}-test.pkl'.format(session_id))

# %%
build_and_save_splits(cifar10_dataset_folder_path)

# %% [markdown]
# ## Checkpoint

# %%
# Run this cell with the timestamp of the run to be loaded if you want to load a different checkpoint
if False:
    session_id = 1596617066

# %%
import pickle

X_train, y_train = pickle.load(open('data/{}-train.pkl'.format(session_id), mode='rb'))
# X_val, y_val = pickle.load(open('data/validation.pkl', mode='rb'))
X_test, y_test = pickle.load(open('data/{}-test.pkl'.format(session_id), mode='rb'))

# %%
from tensorflow.keras.applications import ResNet50

# Init the VGG model 
res_net = ResNet50(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
# Out:
# /Users/nicovendramin/.pyenv/versions/3.7.5/envs/data_science/lib/python3.7/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# Freeze all the layers
for layer in res_net.layers[:]:
    layer.trainable = False

# Check the trainable status of the individual layers
for layer in res_net.layers:
    print(layer, layer.trainable)
    
res_net.summary()
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x14862d1d0> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x14d9373d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1450b0990> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1486292d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1476c4210> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x1450b0e50> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x1450b0ed0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14533f450> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1476f1c90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x148655c50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x148673510> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1486a7490> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1486a7750> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1496aaa50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x149774750> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1496def50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1497c1fd0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1497c1b90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x149854f50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1497e2050> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14a0e14d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14a0e1ed0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14a1a5990> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14a1bf610> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14a1dcc10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14a270fd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14a2dd310> False
# <tensorflow.python.keras.layers.merge.Add object at 0x14a2dd2d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14a37d950> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14d909fd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14d924e10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14d924210> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14dde8b10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14ea68d10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14ea85bd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x179314e10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4900950> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1e493c410> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e49e1990> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4a01fd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4a19dd0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e4a19350> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4addb10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4af5d10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e4b11bd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4ba5e10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4cb1990> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4bd5950> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4cd3a50> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1e4cd3f10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e4d7f690> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4dc9d90> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4deb110> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e4deb290> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4eb3150> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4eb3190> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e4eb3110> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e4f85210> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e4fc2310> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1e4fc2b90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e5069dd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1e509b390> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1e50c02d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1e50c03d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1eee84a50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1eee84050> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1eee849d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1eef59410> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1eef76e90> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1eef93b50> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1ef027750> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1ef06e790> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1ef092310> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1ef092410> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1ef513910> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1ef502590> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1ef502bd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1ef90a210> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1ef947310> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1ef947b90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1ef9eae10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1efa22390> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1efa44310> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1efa44410> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1efb08150> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1efb08190> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1efb08110> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1efbde210> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f04cee10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f043a810> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f04fe210> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f04fe750> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f0589250> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f0da5e90> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f0de6090> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f0de6b50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f0ec3490> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f0efb4d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f0efb6d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f0f9bbd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f0fd7090> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f0fd7ed0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f1067c90> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1096dd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f10d24d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f10d2cd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f11af590> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f11c9e10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f11ea550> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f128d2d0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f12c8590> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f12c8e90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f13577d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1389d10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f13c2110> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f13c2b10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f14a2950> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f14a2310> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f14db590> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f157c210> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f15b8550> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f15b8ed0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f16486d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1677c50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f16b0950> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f16b0a50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f178e410> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f17cb250> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f17cb210> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f186a690> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f188bfd0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f18a5e50> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f19394d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f196a290> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f199c6d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f199c850> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1d05750> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f1d05150> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f1d3a3d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1dadbd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f1e159d0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f1e15d50> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f1ea7f50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1ef5bd0> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f1f10650> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f1f10990> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f1ff3290> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f2006910> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f202f350> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f20c9150> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f219cf50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f20eaf10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f21c8a10> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f21c8fd0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f21fe550> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f6eddd50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f6f45150> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f6f45ed0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f7025750> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f7041710> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f705d710> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f70fe210> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f7136f90> False
# <tensorflow.python.keras.layers.merge.Add object at 0x1f71367d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f71ca7d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x1f7219e10> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x1f7238a90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1f7238510> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14f044f90> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x14f0b22d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x14eb22050> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x14b878e50> False
# <tensorflow.python.keras.layers.normalization.BatchNormalizationV1 object at 0x148606fd0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x148606990> False
# <tensorflow.python.keras.layers.core.Activation object at 0x1485d0190> False
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_11[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalizationV1) (None, 16, 16, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           activation_87[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 8, 8, 64)     0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 8, 8, 64)     4160        max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 8, 8, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 8, 8, 64)     36928       activation_88[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 8, 8, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 64)     0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 8, 8, 256)    16640       activation_89[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 8, 8, 256)    16640       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 8, 8, 256)    1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 8, 8, 256)    1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 8, 8, 64)     16448       activation_90[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 8, 8, 64)     256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 64)     0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 8, 8, 64)     36928       activation_91[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 8, 8, 64)     256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 64)     0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 8, 8, 256)    16640       activation_92[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 8, 8, 256)    1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           bn2b_branch2c[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 256)    0           add_17[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 8, 8, 64)     16448       activation_93[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 8, 8, 64)     256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 8, 8, 64)     0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 8, 8, 64)     36928       activation_94[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 8, 8, 64)     256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 8, 8, 64)     0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 8, 8, 256)    16640       activation_95[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 8, 8, 256)    1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           bn2c_branch2c[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 8, 8, 256)    0           add_18[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 4, 4, 128)    32896       activation_96[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_97[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_98[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 4, 4, 512)    131584      activation_96[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 4, 4, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, 4, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 4, 4, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_99[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 4, 4, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_100[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 4, 4, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_101[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, 4, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 4, 4, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_102[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 4, 4, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_103[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 4, 4, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_104[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, 4, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 4, 4, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_105[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 4, 4, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_106[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 4, 4, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_107[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 4, 4, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 4, 4, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 2, 2, 256)    131328      activation_108[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 2, 2, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_109[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 2, 2, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_110[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 2, 2, 1024)   525312      activation_108[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 2, 2, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 2, 2, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 2, 2, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_111[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 2, 2, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_112[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 2, 2, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_113[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 2, 2, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 2, 2, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_114[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 2, 2, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_115[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 2, 2, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_116[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 2, 2, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_114[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 2, 2, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_117[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 2, 2, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_118[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 2, 2, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_119[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 2, 2, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_117[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 2, 2, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_120[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 2, 2, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_121[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 2, 2, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_122[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 2, 2, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 2, 2, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_123[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 2, 2, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_124[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 2, 2, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_125[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 2, 2, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 2, 2, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 1, 1, 512)    524800      activation_126[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 1, 1, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 1, 1, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 1, 1, 512)    2359808     activation_127[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 1, 1, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 1, 1, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 1, 1, 2048)   1050624     activation_128[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 1, 1, 2048)   2099200     activation_126[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 1, 1, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 1, 1, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1, 1, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 1, 1, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 1, 1, 512)    1049088     activation_129[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 1, 1, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 1, 1, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359808     activation_130[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 1, 1, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 1, 1, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 1, 1, 2048)   1050624     activation_131[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 1, 1, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 1, 1, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_129[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 1, 1, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 1, 1, 512)    1049088     activation_132[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 1, 1, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 1, 1, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 1, 1, 512)    2359808     activation_133[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 1, 1, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 1, 1, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 1, 1, 2048)   1050624     activation_134[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 1, 1, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 1, 1, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_132[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 1, 1, 2048)   0           add_31[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential

# Create the model
model = Sequential()

# Add the vgg convolutional base model
model.add(res_net)
model.summary()

# Add new layers
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 1, 1, 2048)        23587712
# =================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 25,696,138
# Trainable params: 2,108,426
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

model.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'models/res-model-{}.h5'.format(session_id), 
    monitor='val_acc', 
    verbose=0, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'
)

# Train the model
history = model.fit(
    x=X_train,
    y=y_train,
    validation_split=0.2,
    batch_size=512,
    epochs=30,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/30
# 40000/40000 [==============================] - 112s 3ms/sample - loss: 2.4327 - acc: 0.2606 - val_loss: 2.8718 - val_acc: 0.3375
# Epoch 2/30
# 40000/40000 [==============================] - 116s 3ms/sample - loss: 2.0627 - acc: 0.3452 - val_loss: 3.1437 - val_acc: 0.3291
# Epoch 3/30
# 40000/40000 [==============================] - 122s 3ms/sample - loss: 1.8935 - acc: 0.3856 - val_loss: 2.9100 - val_acc: 0.3559
# Epoch 4/30
# 40000/40000 [==============================] - 132s 3ms/sample - loss: 1.7817 - acc: 0.4127 - val_loss: 2.7432 - val_acc: 0.3810
# Epoch 5/30
# 40000/40000 [==============================] - 130s 3ms/sample - loss: 1.7049 - acc: 0.4272 - val_loss: 2.6926 - val_acc: 0.3898
# Epoch 6/30
# 40000/40000 [==============================] - 146s 4ms/sample - loss: 1.6453 - acc: 0.4453 - val_loss: 2.7782 - val_acc: 0.3732
# Epoch 7/30
# 40000/40000 [==============================] - 129s 3ms/sample - loss: 1.5969 - acc: 0.4570 - val_loss: 2.7285 - val_acc: 0.3820
# Epoch 8/30
# 40000/40000 [==============================] - 129s 3ms/sample - loss: 1.5586 - acc: 0.4707 - val_loss: 2.6801 - val_acc: 0.3886
# Epoch 9/30
# 40000/40000 [==============================] - 135s 3ms/sample - loss: 1.5185 - acc: 0.4814 - val_loss: 2.5606 - val_acc: 0.4089
# Epoch 10/30
# 40000/40000 [==============================] - 112s 3ms/sample - loss: 1.4913 - acc: 0.4867 - val_loss: 2.6664 - val_acc: 0.3942
# Epoch 11/30
# 40000/40000 [==============================] - 110s 3ms/sample - loss: 1.4701 - acc: 0.4936 - val_loss: 2.7216 - val_acc: 0.3936
# Epoch 12/30
# 40000/40000 [==============================] - 110s 3ms/sample - loss: 1.4448 - acc: 0.4999 - val_loss: 2.6376 - val_acc: 0.4002
# Epoch 13/30
# 40000/40000 [==============================] - 129s 3ms/sample - loss: 1.4240 - acc: 0.5074 - val_loss: 2.6273 - val_acc: 0.4034
# Epoch 14/30
# 40000/40000 [==============================] - 121s 3ms/sample - loss: 1.4050 - acc: 0.5158 - val_loss: 2.6607 - val_acc: 0.3969
# Epoch 15/30
# 40000/40000 [==============================] - 124s 3ms/sample - loss: 1.3897 - acc: 0.5182 - val_loss: 2.6033 - val_acc: 0.4109
# Epoch 16/30
# 40000/40000 [==============================] - 112s 3ms/sample - loss: 1.3721 - acc: 0.5236 - val_loss: 2.5869 - val_acc: 0.4056
# Epoch 17/30
# 40000/40000 [==============================] - 129s 3ms/sample - loss: 1.3586 - acc: 0.5278 - val_loss: 2.4827 - val_acc: 0.4218
# Epoch 18/30
# 40000/40000 [==============================] - 123s 3ms/sample - loss: 1.3454 - acc: 0.5306 - val_loss: 2.5204 - val_acc: 0.4185
# Epoch 19/30
# 40000/40000 [==============================] - 115s 3ms/sample - loss: 1.3299 - acc: 0.5414 - val_loss: 2.5372 - val_acc: 0.4175
# Epoch 20/30
# 40000/40000 [==============================] - 110s 3ms/sample - loss: 1.3150 - acc: 0.5454 - val_loss: 2.5531 - val_acc: 0.4133
# Epoch 21/30
# 40000/40000 [==============================] - 115s 3ms/sample - loss: 1.3024 - acc: 0.5467 - val_loss: 2.5048 - val_acc: 0.4171
# Epoch 22/30
# 40000/40000 [==============================] - 125s 3ms/sample - loss: 1.2943 - acc: 0.5519 - val_loss: 2.5539 - val_acc: 0.4170
# Epoch 23/30
# 40000/40000 [==============================] - 127s 3ms/sample - loss: 1.2862 - acc: 0.5502 - val_loss: 2.6009 - val_acc: 0.4113
# Epoch 24/30
# 40000/40000 [==============================] - 132s 3ms/sample - loss: 1.2780 - acc: 0.5577 - val_loss: 2.5190 - val_acc: 0.4197
# Epoch 25/30
# 40000/40000 [==============================] - 144s 4ms/sample - loss: 1.2629 - acc: 0.5607 - val_loss: 2.5286 - val_acc: 0.4180
# Epoch 26/30
# 40000/40000 [==============================] - 155s 4ms/sample - loss: 1.2562 - acc: 0.5641 - val_loss: 2.6128 - val_acc: 0.4105
# Epoch 27/30
# 40000/40000 [==============================] - 141s 4ms/sample - loss: 1.2403 - acc: 0.5706 - val_loss: 2.5530 - val_acc: 0.4174
# Epoch 28/30
# 40000/40000 [==============================] - 160s 4ms/sample - loss: 1.2330 - acc: 0.5740 - val_loss: 2.6286 - val_acc: 0.4148
# Epoch 29/30
# 40000/40000 [==============================] - 141s 4ms/sample - loss: 1.2279 - acc: 0.5737 - val_loss: 2.6063 - val_acc: 0.4148
# Epoch 30/30
# 40000/40000 [==============================] - 142s 4ms/sample - loss: 1.2206 - acc: 0.5767 - val_loss: 2.6342 - val_acc: 0.4155

# %% [markdown]
# ### Show Stats

# %%
import json
import pandas as pd
#with open('history.json', 'w') as f:
#    json.dump(history.history, f)

history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['acc', 'val_acc']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Fully Train the Model

# %%
model.load_weights('models/res-model-{}.h5'.format(session_id))
train_loss, train_score = model.evaluate(X_train, y_train)
test_loss, test_score = model.evaluate(X_test, y_test)
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
print("Train F1 Score:", train_score)
print("Test F1 Score:", test_score)
# Out:
# 50000/50000 [==============================] - 139s 3ms/sample - loss: 2.4628 - acc: 0.4290
# 10000/10000 [==============================] - 32s 3ms/sample - loss: 2.5030 - acc: 0.4206
# Train Loss: 2.4627914379882814
# Test Loss: 2.5030496353149414
# Train F1 Score: 0.42896
# Test F1 Score: 0.4206

# %%
def predict_vector(sample):
    vector = model.predict(np.reshape(sample, (1,32,32,3)))[0]
    return vector

def predict_label(sample):
    vector = model.predict(np.reshape(sample, (1,32,32,3)))[0]
    return to_label_id(vector)
    
def to_label_id(label_vector):
    return np.argmax(label_vector)

def display_stats(sample_image, sample_label, predicted_label):
    
    label_names = load_label_names()
    
    print('\nExample of Image:')
    print('Image - Shape: {}'.format(sample_image.shape))
    print('Label - Label Id: {} Name: {}'.format(sample_label, label_names[sample_label]))
    print('Predicted Label - Label Id: {} Name: {}'.format(predicted_label, label_names[predicted_label]))
    
    plt.imshow(sample_image)
    
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np

# Explore the dataset
import random
image_id = random.randint(0, len(X_test))
display_stats(X_train[image_id], to_label_id(y_train[image_id]), predict_label(X_train[image_id]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Example of Image:
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog
# Predicted Label - Label Id: 5 Name: dog

# %%
def random_sample(X, y, k):
    a = list(np.arange(0, len(X)))
    c = random.sample(a, k)
    sample_X = []
    sample_y = []
    for i in c:
        sample_X.append(X[i])
        sample_y.append(y[i])
    return sample_X, sample_y

random_sample(X_test, y_test, 12)

def display_image_predictions(features, labels, top_n_predictions):
    n_classes = 10
    label_names = load_label_names()
    label_ids = [to_label_id(label) for label in labels]
    predictions = [predict_vector(feature) for feature in features]
    predictions_indices = []
    predictions_values = []
    for prediction in predictions:
        a = np.arange(0, len(prediction))
        b = list(zip(list(a), prediction))
        b = sorted(b, key=lambda x: x[1])
        c = list(map(lambda x: x[0], b))
        d = list(map(lambda x: x[1], b))
        predictions_indices.append(c[-top_n_predictions:])
        predictions_values.append(d[-top_n_predictions:])
        
    fig, axies = plt.subplots(nrows=top_n_predictions, ncols=2, figsize=(20, 10))
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions
   
    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions_indices, predictions_values)):
        if (image_i < top_n_predictions):
            pred_names = [label_names[pred_i] for pred_i in pred_indicies]
            correct_name = label_names[label_id]
            
            axies[image_i][0].imshow((feature*255).astype(np.int32, copy=False))
            axies[image_i][0].set_title(correct_name)
            axies[image_i][0].set_axis_off()

            axies[image_i][1].barh(ind + margin, pred_values[-3:], width)
            axies[image_i][1].set_yticks(ind + margin)
            axies[image_i][1].set_yticklabels(pred_names[-3:])
            axies[image_i][1].set_xticks([0, 0.5, 1.0])

features_, labels_ = random_sample(X_test, y_test, 12)

display_image_predictions(features_, labels_, 5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          title="Confusion Matrix",
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    #Print Confusion matrix
    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Making prediction
y_pred=model.predict_classes(X_test)
y_true=np.argmax(y_test,axis=1)

#Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx=confusion_matrix(y_true,y_pred)

class_names= load_label_names()

# Plotting non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes = class_names)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>
